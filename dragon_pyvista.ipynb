# %%
import pyvista
from pyvista import examples
mesh = examples.download_dragon()
#mesh['scalars'] = mesh.points[:, 1]
mesh.plot(cpos='xy', cmap='plasma', pbr=True, metallic=4.0, roughness=0.5,
          zoom=1.7)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
